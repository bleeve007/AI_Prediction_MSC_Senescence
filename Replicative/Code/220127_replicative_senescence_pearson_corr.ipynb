# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from PIL import Image
import glob

np.set_printoptions(threshold=np.inf)

# %%
def file_import(path, background):
    image_list = []
    for filename in glob.glob(path):
        im = Image.open(filename).convert("L")
        imarray = np.asarray(im)
        imarray = imarray[imarray != background]
        image_list.append(imarray)
    return image_list

def pearsonr_1D(x, y):
    if (x.size != y.size):
        return None
    
    xm = x - np.mean(x)
    ym = y - np.mean(y)
    upper = np.sum(xm * ym)
    lower = np.sqrt(np.sum(np.power(xm, 2)) * np.sum(np.power(ym, 2)))
    
    if (lower == 0):
        return None
    
    rho = upper / lower
    return rho

# %%
cd105_FBS_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P2\cd105_Prediction\*.tif", 255)
cd105_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P4\cd105_Prediction\*.tif", 255)
cd105_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P6\cd105_Prediction\*.tif", 255)
cd105_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P8\cd105_Prediction\*.tif", 255)
cd105_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P10\cd105_Prediction\*.tif", 255)

cd105_FBS_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P2\cd105_Target\*.tif", 255)
cd105_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P4\cd105_Target\*.tif", 255)
cd105_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P6\cd105_Target\*.tif", 255)
cd105_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P8\cd105_Target\*.tif", 255)
cd105_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P10\cd105_Target\*.tif", 255)


cd105_FBS_pearsonr_values = []
for pred, target in zip(cd105_FBS_pred, cd105_FBS_target):
    cd105_FBS_pearsonr_values.append(pearsonr_1D(pred, target))
    
cd105_FBS_pearsonr_values = list(filter(lambda intensity: intensity != None, cd105_FBS_pearsonr_values))
    
print (cd105_FBS_pearsonr_values)
# Out:
# [0.3733720900154703, 0.5666072667338411, 0.6954222858496842, 0.4377768153642892, 0.45325480661013384, 0.554769328843881, 0.35013479734704017, 0.30711783298947, 0.3863756701675949, 0.44371596335279506, 0.45123651000036913, 0.2953232359334859, 0.5728466082708514, 0.5603267308476416, 0.33069905129777705, 0.8193856167118537, 0.6560610744804933, 0.4035031696798406, 0.6050291678141672, 0.3969689260726267, 0.3586813249159197, 0.3923836934323339, 0.28305500453245785, 0.5035505961851852, 0.45375696789792047, 0.10228618768890747, 0.24296761728520797, 0.16042701632535838, 0.25628550182185034, 0.18618707893166106, 0.12522879791630345, 0.15781540487691012, 0.5673157355740287, 0.1651394102967764, 0.015355503277551478, 0.1286656788397385, 0.10710866153791014, 0.1538479291745796, 0.20327881891132837, 0.1575928016667257, 0.17649915344341388, 0.26326296696084284, 0.13906750505184814, 0.09302034729880604, 0.241353608102046, 0.220422336857926, 0.14856210065982128, 0.1287724147562769, 0.12922497717060505
# ...

# %%
p16_FBS_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P2\p16_Prediction\*.tif", 255)
p16_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P4\p16_Prediction\*.tif", 255)
p16_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P6\p16_Prediction\*.tif", 255)
p16_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P8\p16_Prediction\*.tif", 255)
p16_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P10\p16_Prediction\*.tif", 255)

p16_FBS_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P2\p16_Target\*.tif", 255)
p16_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P4\p16_Target\*.tif", 255)
p16_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P6\p16_Target\*.tif", 255)
p16_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P8\p16_Target\*.tif", 255)
p16_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\P10\p16_Target\*.tif", 255)

p16_FBS_pearsonr_values = []
for pred, target in zip(p16_FBS_pred, p16_FBS_target):
    p16_FBS_pearsonr_values.append(pearsonr_1D(pred, target))
    
p16_FBS_pearsonr_values = list(filter(lambda intensity: intensity != None, p16_FBS_pearsonr_values))
    
print (p16_FBS_pearsonr_values)
# Out:
# [0.4063741686382121, 0.4569157114288091, 0.06060388502638087, 0.4259830447007078, 0.3671777421515367, 0.5354800319713071, 0.3974663222008076, 0.2614726969844117, 0.17036675509442772, 0.37292641167164886, 0.2729900803444534, 0.17837913635287658, 0.4402164184816668, 0.30390109006720645, 0.20745216281380252, 0.4072386313094398, 0.7942637190236986, 0.232038205931776, 0.5583098555280436, 0.2385419976039148, 0.2728009472195615, 1.0, 0.22874627470999442, 0.2292548911758522, 0.4906002918973884, 0.12534623887543536, 0.13573887190306547, 0.2554579662076885, 0.18927182210530696, 0.12304151881880226, 0.15720105016550165, 0.16828339542504975, 0.22059105394251108, 0.27360005742436005, 0.42117337662441867, 0.11101824912943353, 0.14579160460188798, 0.10319662372201664, 0.08913151949375289, 0.2516816549219127, 0.2092936577006568, 0.11793844358229907, 0.3452851939993169, 0.10163911151466827, 0.5089142273031917, 0.13897567994389876, 0.24195498305713517, 0.21818080109987295, 0.14369286132277773, 0.11215
# ...

# %%
CCND2_FBS_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P2\CCND2_Prediction\*.tif", 255)
CCND2_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P4\CCND2_Prediction\*.tif", 255)
CCND2_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P6\CCND2_Prediction\*.tif", 255)
CCND2_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P8\CCND2_Prediction\*.tif", 255)
CCND2_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P10\CCND2_Prediction\*.tif", 255)

CCND2_FBS_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P2\CCND2_Target\*.tif", 255)
CCND2_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P4\CCND2_Target\*.tif", 255)
CCND2_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P6\CCND2_Target\*.tif", 255)
CCND2_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P8\CCND2_Target\*.tif", 255)
CCND2_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P10\CCND2_Target\*.tif", 255)


CCND2_FBS_pearsonr_values = []
for pred, target in zip(CCND2_FBS_pred, CCND2_FBS_target):
    CCND2_FBS_pearsonr_values.append(pearsonr_1D(pred, target))
    
CCND2_FBS_pearsonr_values = list(filter(lambda intensity: intensity != None, CCND2_FBS_pearsonr_values))
    
print (CCND2_FBS_pearsonr_values)
# Out:
# [0.1510788930235361, -0.037090515688569616, 0.024767191976331045, 0.04063241010963757, 0.06824959154341602, 0.027761557929260168, 0.022184566237332618, 0.008686917531463388, 0.13881483929806343, 0.026181253717364628, 0.04890059962818047, 0.0578151181953048, -0.006272584970409409, 0.09153908820737901, 0.07010358572888205, 0.06709215476329596, 0.11200565485029604, 0.0850294526456569, 0.13336804596557295, 0.07150504775197414, 0.06613948562349395, 0.02034350171917371, 0.03703481361592702, 0.000530222589180542, 0.057025320226746695, 0.11309083766870937, 0.14064084452877026, 0.08649015821217865, 0.08445190904756292, 0.15975155195828095, 0.12841301374810243, 0.054299214475602875, 0.11051296281757729, 0.14241327315427454, 0.09860826132967423, 0.07297874162812963, 0.048756760436945455, 0.1262153859539995, 0.06849282491866669, 0.059873823632919355, 0.055516039602313175, 0.5424617634134792, 0.08781807314337758, 0.10298976951720087, 0.06904877485825159, 0.0750050050896324, 0.04621852588804201, 0
# ...

# %%
p38_FBS_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P2\p38_Prediction\*.tif", 255)
p38_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P4\p38_Prediction\*.tif", 255)
p38_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P6\p38_Prediction\*.tif", 255)
p38_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P8\p38_Prediction\*.tif", 255)
p38_FBS_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P10\p38_Prediction\*.tif", 255)

p38_FBS_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P2\p38_Target\*.tif", 255)
p38_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P4\p38_Target\*.tif", 255)
p38_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P6\p38_Target\*.tif", 255)
p38_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P8\p38_Target\*.tif", 255)
p38_FBS_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\P10\p38_Target\*.tif", 255)


p38_FBS_pearsonr_values = []
for pred, target in zip(p38_FBS_pred, p38_FBS_target):
    p38_FBS_pearsonr_values.append(pearsonr_1D(pred, target))
    
p38_FBS_pearsonr_values = list(filter(lambda intensity: intensity != None, p38_FBS_pearsonr_values))
    
print (p38_FBS_pearsonr_values)
# Out:
# [0.6750565932974301, 0.46577663594441543, 0.49880655426324244, 0.4146644488433818, 0.46395103336761495, 0.42068787539813685, 0.5545259094882978, 0.3881671567565807, 0.44986467783084355, 0.5040568032665127, 0.39696922403606233, 0.4271333545762421, 0.3003472131555186, 0.4810328817376943, 0.5292308770081495, 0.4280666108043991, 0.31649098967147643, 0.434864505673884, 0.4761884291384122, 0.5428396976328772, 0.6994296086322246, 0.39583637919078885, 0.3868411862540259, 0.44454603357136596, 0.3490780805727894, 0.14120129880295465, 0.13367053134884258, 0.09832065876320598, 0.07494364629375166, 0.13563151061612627, 0.2897944735862782, 0.007105956398279858, 0.07228730157538184, 0.08092511357343303, 0.1293236702364422, 0.07160771283842156, 0.10130624856416075, 0.04936351349435304, 0.16770415696367177, 0.11209394431434692, 0.08635317511668394, 0.015976077981558853, 0.09497670778683188, 0.059430540404060615, 0.14636650701737564, 0.10862270110690211, 0.08125823677593651, 0.10106984213026504, 0.156
# ...

# %%
cd105_Stemfit_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P2\cd105_Prediction\*.tif", 255)
cd105_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P4\cd105_Prediction\*.tif", 255)
cd105_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P6\cd105_Prediction\*.tif", 255)
cd105_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P8\cd105_Prediction\*.tif", 255)
cd105_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P10\cd105_Prediction\*.tif", 255)

cd105_Stemfit_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P2\cd105_Target\*.tif", 255)
cd105_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P4\cd105_Target\*.tif", 255)
cd105_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P6\cd105_Target\*.tif", 255)
cd105_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P8\cd105_Target\*.tif", 255)
cd105_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P10\cd105_Target\*.tif", 255)


cd105_Stemfit_pearsonr_values = []
for pred, target in zip(cd105_Stemfit_pred, cd105_Stemfit_target):
    cd105_Stemfit_pearsonr_values.append(pearsonr_1D(pred, target))
    
cd105_Stemfit_pearsonr_values = list(filter(lambda intensity: intensity != None, cd105_Stemfit_pearsonr_values))
    
print (cd105_Stemfit_pearsonr_values)
# Out:
# [0.10155491938274606, 0.06077895132843376, 0.0632091208198127, 0.14274076839196392, 0.08982077600843019, 0.029789435032172528, 0.09785110437706904, 0.07923660518421684, 0.08992571628269953, -0.002816398259763676, 0.06366305277532686, -0.01302944775931877, 0.039758290918377646, 0.15673019237833102, 0.07940358260753701, 0.09020410626969302, 0.056495795913211404, 0.03680155730369694, 0.023203683308766532, 0.09012235395132596, 0.1599249297290939, 0.03018843906165452, 0.09561781029403273, 0.008391320690678996, 0.0857979430956751, 0.2306882564210227, 0.28667984037885885, 0.28573414325434743, 0.4163654184065347, 0.20204557556327812, 0.2658773609354267, 0.3311979483912112, 0.22541518101085678, 0.21645695713314667, 0.1938446078750863, 0.2288532746088734, 0.21088283772358193, 0.23448666814265576, 0.13677252540716633, 0.2941103036919689, 0.19006453089266942, 0.2074898040888475, 0.3723221110321874, 0.13164052594273826, 0.17609476139318625, 0.48087319661754835, 0.269821697847185, 0.30136267695535
# ...

# %%
p16_Stemfit_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P2\p16_Prediction\*.tif", 255)
p16_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P4\p16_Prediction\*.tif", 255)
p16_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P6\p16_Prediction\*.tif", 255)
p16_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P8\p16_Prediction\*.tif", 255)
p16_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P10\p16_Prediction\*.tif", 255)

p16_Stemfit_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P2\p16_Target\*.tif", 255)
p16_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P4\p16_Target\*.tif", 255)
p16_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P6\p16_Target\*.tif", 255)
p16_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P8\p16_Target\*.tif", 255)
p16_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\P10\p16_Target\*.tif", 255)

p16_Stemfit_pearsonr_values = []
for pred, target in zip(p16_Stemfit_pred, p16_Stemfit_target):
    p16_Stemfit_pearsonr_values.append(pearsonr_1D(pred, target))
    
p16_Stemfit_pearsonr_values = list(filter(lambda intensity: intensity != None, p16_Stemfit_pearsonr_values))
    
print (p16_Stemfit_pearsonr_values)
# Out:
# [-0.03274090721945513, 0.09457209253479718, 0.03812015163587592, 0.056603228488069784, -0.03494954148825559, -0.01203674012506373, -0.104692547629215, 0.20427621094500653, 0.0685404159527973, -0.02753326008938766, 0.2117656624526427, 0.290750240436328, 0.3164344382065579, 0.7029761429328344, 0.03325012973279057, 0.13320554794978198, 0.19910263725677294, 0.22927877332856395, 0.08720372805475866, 0.13926744017644807, 0.2402393694286124, 0.485334373576792, 0.01945494139737616, -0.030471093068519698, 0.12829828260860818, 0.2782094336842249, 0.32277341905095436, 0.4389467393850937, 0.6254457223541031, 0.0277296258138167, 0.1759514362293051, 0.5764830235564441, 0.22097336755952698, 0.541538134430022, 0.49055013487521554, 0.5229543421245533, 0.0916100482926805, 0.7071509831439203, 0.40856489556360703, 0.3935173242058289, 0.3858500327212732, 0.34490500002962066, 0.39488943420131206, 0.07998021263109718, 0.6997798669883742, 0.46937055092947666, 0.6891310539615584, 0.511347924623187, 0.1122261
# ...

# %%
CCND2_Stemfit_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P2\CCND2_Prediction\*.tif", 255)
CCND2_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P4\CCND2_Prediction\*.tif", 255)
CCND2_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P6\CCND2_Prediction\*.tif", 255)
CCND2_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P8\CCND2_Prediction\*.tif", 255)
CCND2_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P10\CCND2_Prediction\*.tif", 255)

CCND2_Stemfit_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P2\CCND2_Target\*.tif", 255)
CCND2_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P4\CCND2_Target\*.tif", 255)
CCND2_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P6\CCND2_Target\*.tif", 255)
CCND2_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P8\CCND2_Target\*.tif", 255)
CCND2_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P10\CCND2_Target\*.tif", 255)


CCND2_Stemfit_pearsonr_values = []
for pred, target in zip(CCND2_Stemfit_pred, CCND2_Stemfit_target):
    CCND2_Stemfit_pearsonr_values.append(pearsonr_1D(pred, target))
    
CCND2_Stemfit_pearsonr_values = list(filter(lambda intensity: intensity != None, CCND2_Stemfit_pearsonr_values))
    
print (CCND2_Stemfit_pearsonr_values)
# Out:
# [0.1410436378139669, 0.04591104512575919, 0.0879284769399445, 0.06485951980114758, 0.11442458873772532, 0.06078007604348962, 0.07645048065703951, 0.06916065531416002, 0.04458973431870799, 0.05766762355061391, 0.08996905839445993, 0.05612800961531221, 0.09388554649911514, 0.10380113114868467, 0.0665226727666047, 0.060954020028256756, 0.10153217493751493, 0.06752429158431081, 0.04363376444266053, 0.07801908314509512, 0.03521552928349429, 0.07862282198813397, 0.08845508820042945, 0.04714371822314743, 0.06131416367215503, 0.09823063403244246, 0.09653671384971098, 0.1358927459028401, 0.0886756072326584, 0.08682975593441353, 0.06942967044328963, 0.05492276485667894, 0.10604032376228625, 0.10026340104688648, 0.07843568176209625, 0.01748809152787976, 0.10495662930578128, 0.10173280109882532, 0.10836316838238728, 0.10667062050166094, 0.1957286277207838, 0.1273923893036585, 0.1019911673025188, 0.10082556918240736, 0.0830258012743624, 0.11350576497325608, 0.0770589572463337, 0.06565172622468962
# ...

# %%
p38_Stemfit_pred = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P2\p38_Prediction\*.tif", 255)
p38_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P4\p38_Prediction\*.tif", 255)
p38_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P6\p38_Prediction\*.tif", 255)
p38_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P8\p38_Prediction\*.tif", 255)
p38_Stemfit_pred += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P10\p38_Prediction\*.tif", 255)

p38_Stemfit_target = file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P2\p38_Target\*.tif", 255)
p38_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P4\p38_Target\*.tif", 255)
p38_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P6\p38_Target\*.tif", 255)
p38_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P8\p38_Target\*.tif", 255)
p38_Stemfit_target += file_import(r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\P10\p38_Target\*.tif", 255)


p38_Stemfit_pearsonr_values = []
for pred, target in zip(p38_Stemfit_pred, p38_Stemfit_target):
    p38_Stemfit_pearsonr_values.append(pearsonr_1D(pred, target))
    
p38_Stemfit_pearsonr_values = list(filter(lambda intensity: intensity != None, p38_Stemfit_pearsonr_values))
    
print (p38_Stemfit_pearsonr_values)
# Out:
# [0.3208035425413181, 0.2742302026516128, 0.2576194925534373, 0.18073506697961583, 0.20981134357992767, 0.2565539093865137, 0.22714531904784568, 0.29170555338645293, 0.1575659594833212, 0.20201259723867473, 0.26626052812214546, 0.16222312807722347, 0.12410245276648323, 0.5113418154735386, 0.20910491117699156, 0.2904429903639326, 0.22263080665978338, 0.3481595111252707, 0.21845146480268227, 0.480625854002418, 0.1723766371174702, 0.14695220385196694, 0.24928960711527387, 0.1838353197862268, 0.2544272601894264, 0.1255806711825391, 0.14137269546848374, 0.14924117203089782, 0.13098615737846228, 0.10872718025232228, 0.1488929596052559, 0.12082089595606715, 0.1499612536878677, 0.13749946439044772, 0.0823697414496624, 0.08999485182958163, 0.17473466868699403, 0.1737478195252392, -0.0028658796570478072, 0.17467495252410273, 0.10268813849934155, 0.0860951107673183, 0.1009452918253556, 0.24996392787293448, 0.1046143154518361, 0.04944405507818177, -0.0053621271965960315, 0.11353013497183168, 0.30
# ...

# %%
fig, ax = plt.subplots()

color1 = '#ff0000'
color2 = '#0000ff'

def set_box_color (bp):
    plt.setp (bp['boxes'][0], color = color1)
    plt.setp (bp['whiskers'][0], color = color1)
    plt.setp (bp['whiskers'][1], color = color1)
    plt.setp (bp['caps'][0], color = color1)
    plt.setp (bp['caps'][1], color = color1)
    plt.setp (bp['medians'][0], color = 'black')
    plt.setp (bp['medians'][0], color = 'black')
    
    plt.setp (bp['boxes'][1], color = color2)
    plt.setp (bp['whiskers'][2], color = color2)
    plt.setp (bp['whiskers'][3], color = color2)
    plt.setp (bp['caps'][2], color = color2)
    plt.setp (bp['caps'][3], color = color2)
    plt.setp (bp['medians'][1], color = 'black')
    plt.setp (bp['medians'][1], color = 'black')

# Rectangular Box Plot with Data
cd105_bplot = ax.boxplot ([cd105_FBS_pearsonr_values, cd105_Stemfit_pearsonr_values], vert = True, patch_artist = True, positions = [1,2],  widths = 0.8, flierprops = {'marker': 'x'})
set_box_color (cd105_bplot)

p16_bplot = ax.boxplot ([p16_FBS_pearsonr_values, p16_Stemfit_pearsonr_values], vert = True, patch_artist = True, positions = [4,5],  widths = 0.8, flierprops = {'marker': 'x'})
set_box_color (p16_bplot)

CCND2_bplot = ax.boxplot ([CCND2_FBS_pearsonr_values, CCND2_Stemfit_pearsonr_values], patch_artist = True, vert = True, positions = [7,8],  widths = 0.8, flierprops = {'marker': 'x'})
set_box_color (CCND2_bplot)

p38_bplot = ax.boxplot ([p38_FBS_pearsonr_values, p38_Stemfit_pearsonr_values], patch_artist = True, vert = True, positions = [10,11],  widths = 0.8, flierprops = {'marker': 'x'})
set_box_color (p38_bplot)

# Organize Plot
xlim (0, 12)
ylim (-0.2, 1.2)
ax.set_xticks([1.5, 4.5, 7.5, 10.5])
ax.set_xticklabels (['CD105', 'p16', 'CCND2', 'p38'])

plt.title ("Single Cell Pearson Correlation Coefficient")
plt.ylabel ("Pearson Correlation Coefficient (r)")

plt.plot([], c = color1, label = 'FBS')
plt.plot([], c = color2, label = 'Stemfit')
plt.legend()

plt.savefig("High resoltion.png",dpi = 300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19108/3335425066.py in <module>
#      35
#      36 # Organize Plot
# ---> 37 xlim (0, 12)
#      38 ylim (-0.2, 1.2)
#      39 ax.set_xticks([1.5, 4.5, 7.5, 10.5])
#
# NameError: name 'xlim' is not defined
