# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
p2_cd105_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_prediction.xlsx", sheet_name = "P2")
p4_cd105_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_prediction.xlsx", sheet_name = "P4")
p6_cd105_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_prediction.xlsx", sheet_name = "P6")
p8_cd105_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_prediction.xlsx", sheet_name = "P8")
p10_cd105_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_prediction.xlsx", sheet_name = "P10")

p2_cd105_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_target.xlsx", sheet_name = "P2")
p4_cd105_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_target.xlsx", sheet_name = "P4")
p6_cd105_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_target.xlsx", sheet_name = "P6")
p8_cd105_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_target.xlsx", sheet_name = "P8")
p10_cd105_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_cd105_target.xlsx", sheet_name = "P10")

p2_cd105_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_prediction.xlsx", sheet_name = "P2")
p4_cd105_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_prediction.xlsx", sheet_name = "P4")
p6_cd105_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_prediction.xlsx", sheet_name = "P6")
p8_cd105_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_prediction.xlsx", sheet_name = "P8")
p10_cd105_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_prediction.xlsx", sheet_name = "P10")

p2_cd105_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_target.xlsx", sheet_name = "P2")
p4_cd105_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_target.xlsx", sheet_name = "P4")
p6_cd105_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_target.xlsx", sheet_name = "P6")
p8_cd105_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_target.xlsx", sheet_name = "P8")
p10_cd105_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_cd105_target.xlsx", sheet_name = "P10")

# %%
p2_p16_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_prediction.xlsx", sheet_name = "P2")
p4_p16_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_prediction.xlsx", sheet_name = "P4")
p6_p16_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_prediction.xlsx", sheet_name = "P6")
p8_p16_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_prediction.xlsx", sheet_name = "P8")
p10_p16_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_prediction.xlsx", sheet_name = "P10")

p2_p16_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_target.xlsx", sheet_name = "P2")
p4_p16_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_target.xlsx", sheet_name = "P4")
p6_p16_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_target.xlsx", sheet_name = "P6")
p8_p16_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_target.xlsx", sheet_name = "P8")
p10_p16_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\FBS\211111_FBS_p16_target.xlsx", sheet_name = "P10")

p2_p16_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_prediction.xlsx", sheet_name = "P2")
p4_p16_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_prediction.xlsx", sheet_name = "P4")
p6_p16_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_prediction.xlsx", sheet_name = "P6")
p8_p16_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_prediction.xlsx", sheet_name = "P8")
p10_p16_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_prediction.xlsx", sheet_name = "P10")

p2_p16_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_target.xlsx", sheet_name = "P2")
p4_p16_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_target.xlsx", sheet_name = "P4")
p6_p16_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_target.xlsx", sheet_name = "P6")
p8_p16_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_target.xlsx", sheet_name = "P8")
p10_p16_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\211111_p16_cd105_replicative\Selections\Stemfit\211111_Stemfit_p16_target.xlsx", sheet_name = "P10")

# %%
p2_CCND2_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_prediction.xlsx", sheet_name = "P2")
p4_CCND2_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_prediction.xlsx", sheet_name = "P4")
p6_CCND2_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_prediction.xlsx", sheet_name = "P6")
p8_CCND2_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_prediction.xlsx", sheet_name = "P8")
p10_CCND2_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_prediction.xlsx", sheet_name = "P10")

p2_CCND2_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_target.xlsx", sheet_name = "P2")
p4_CCND2_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_target.xlsx", sheet_name = "P4")
p6_CCND2_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_target.xlsx", sheet_name = "P6")
p8_CCND2_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_target.xlsx", sheet_name = "P8")
p10_CCND2_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_CCND2_target.xlsx", sheet_name = "P10")

p2_CCND2_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_prediction.xlsx", sheet_name = "P2")
p4_CCND2_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_prediction.xlsx", sheet_name = "P4")
p6_CCND2_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_prediction.xlsx", sheet_name = "P6")
p8_CCND2_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_prediction.xlsx", sheet_name = "P8")
p10_CCND2_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_prediction.xlsx", sheet_name = "P10")

p2_CCND2_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_target.xlsx", sheet_name = "P2")
p4_CCND2_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_target.xlsx", sheet_name = "P4")
p6_CCND2_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_target.xlsx", sheet_name = "P6")
p8_CCND2_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_target.xlsx", sheet_name = "P8")
p10_CCND2_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_CCND2_target.xlsx", sheet_name = "P10")

# %%
p2_p38_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_prediction.xlsx", sheet_name = "P2")
p4_p38_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_prediction.xlsx", sheet_name = "P4")
p6_p38_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_prediction.xlsx", sheet_name = "P6")
p8_p38_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_prediction.xlsx", sheet_name = "P8")
p10_p38_FBS_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_prediction.xlsx", sheet_name = "P10")

p2_p38_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_target.xlsx", sheet_name = "P2")
p4_p38_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_target.xlsx", sheet_name = "P4")
p6_p38_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_target.xlsx", sheet_name = "P6")
p8_p38_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_target.xlsx", sheet_name = "P8")
p10_p38_FBS_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\FBS_outlinings\220126_FBS_p38_target.xlsx", sheet_name = "P10")

p2_p38_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_prediction.xlsx", sheet_name = "P2")
p4_p38_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_prediction.xlsx", sheet_name = "P4")
p6_p38_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_prediction.xlsx", sheet_name = "P6")
p8_p38_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_prediction.xlsx", sheet_name = "P8")
p10_p38_stemfit_pred = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_prediction.xlsx", sheet_name = "P10")

p2_p38_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_target.xlsx", sheet_name = "P2")
p4_p38_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_target.xlsx", sheet_name = "P4")
p6_p38_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_target.xlsx", sheet_name = "P6")
p8_p38_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_target.xlsx", sheet_name = "P8")
p10_p38_stemfit_target = pd.read_excel (r"C:\Users\Brandon\Desktop\Work\Lin_Lab\MSC\Data\220126_CCND2_p38\Selections\Stemfit_outlinings\220126_Stemfit_p38_target.xlsx", sheet_name = "P10")

# %%
plt.scatter (p2_cd105_FBS_target.Mean, p2_cd105_FBS_pred.Mean, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_cd105_FBS_target.Mean, p4_cd105_FBS_pred.Mean, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_cd105_FBS_target.Mean, p6_cd105_FBS_pred.Mean, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_cd105_FBS_target.Mean, p8_cd105_FBS_pred.Mean, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_cd105_FBS_target.Mean, p10_cd105_FBS_pred.Mean, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_cd105_stemfit_target.Mean, p2_cd105_stemfit_pred.Mean, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_cd105_stemfit_target.Mean, p4_cd105_stemfit_pred.Mean, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_cd105_stemfit_target.Mean, p6_cd105_stemfit_pred.Mean, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_cd105_stemfit_target.Mean, p8_cd105_stemfit_pred.Mean, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_cd105_stemfit_target.Mean, p10_cd105_stemfit_pred.Mean, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("CD105")
plt.xlabel ("Mean Target Intensity")
plt.ylabel ("Mean Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_p16_FBS_target.Mean, p2_p16_FBS_pred.Mean, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_p16_FBS_target.Mean, p4_p16_FBS_pred.Mean, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_p16_FBS_target.Mean, p6_p16_FBS_pred.Mean, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_p16_FBS_target.Mean, p8_p16_FBS_pred.Mean, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_p16_FBS_target.Mean, p10_p16_FBS_pred.Mean, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_p16_stemfit_target.Mean, p2_p16_stemfit_pred.Mean, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_p16_stemfit_target.Mean, p4_p16_stemfit_pred.Mean, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_p16_stemfit_target.Mean, p6_p16_stemfit_pred.Mean, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_p16_stemfit_target.Mean, p8_p16_stemfit_pred.Mean, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_p16_stemfit_target.Mean, p10_p16_stemfit_pred.Mean, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("p16")
plt.xlabel ("Mean Target Intensity")
plt.ylabel ("Mean Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_CCND2_FBS_target.Mean, p2_CCND2_FBS_pred.Mean, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_CCND2_FBS_target.Mean, p4_CCND2_FBS_pred.Mean, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_CCND2_FBS_target.Mean, p6_CCND2_FBS_pred.Mean, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_CCND2_FBS_target.Mean, p8_CCND2_FBS_pred.Mean, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_CCND2_FBS_target.Mean, p10_CCND2_FBS_pred.Mean, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_CCND2_stemfit_target.Mean, p2_CCND2_stemfit_pred.Mean, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_CCND2_stemfit_target.Mean, p4_CCND2_stemfit_pred.Mean, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_CCND2_stemfit_target.Mean, p6_CCND2_stemfit_pred.Mean, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_CCND2_stemfit_target.Mean, p8_CCND2_stemfit_pred.Mean, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_CCND2_stemfit_target.Mean, p10_CCND2_stemfit_pred.Mean, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("CCND2")
plt.xlabel ("Mean Target Intensity")
plt.ylabel ("Mean Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_p38_FBS_target.Mean, p2_p38_FBS_pred.Mean, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_p38_FBS_target.Mean, p4_p38_FBS_pred.Mean, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_p38_FBS_target.Mean, p6_p38_FBS_pred.Mean, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_p38_FBS_target.Mean, p8_p38_FBS_pred.Mean, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_p38_FBS_target.Mean, p10_p38_FBS_pred.Mean, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_p38_stemfit_target.Mean, p2_p38_stemfit_pred.Mean, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_p38_stemfit_target.Mean, p4_p38_stemfit_pred.Mean, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_p38_stemfit_target.Mean, p6_p38_stemfit_pred.Mean, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_p38_stemfit_target.Mean, p8_p38_stemfit_pred.Mean, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_p38_stemfit_target.Mean, p10_p38_stemfit_pred.Mean, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("p38")
plt.xlabel ("Mean Target Intensity")
plt.ylabel ("Mean Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_cd105_FBS_target.Mean * p2_cd105_FBS_target.Area, p2_cd105_FBS_pred.Mean * p2_cd105_FBS_pred.Area, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_cd105_FBS_target.Mean * p4_cd105_FBS_target.Area, p4_cd105_FBS_pred.Mean * p4_cd105_FBS_pred.Area, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_cd105_FBS_target.Mean * p6_cd105_FBS_target.Area, p6_cd105_FBS_pred.Mean * p6_cd105_FBS_pred.Area, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_cd105_FBS_target.Mean * p8_cd105_FBS_target.Area, p8_cd105_FBS_pred.Mean * p8_cd105_FBS_pred.Area, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_cd105_FBS_target.Mean * p10_cd105_FBS_target.Area, p10_cd105_FBS_pred.Mean * p10_cd105_FBS_pred.Area, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_cd105_stemfit_target.Mean * p2_cd105_stemfit_target.Area, p2_cd105_stemfit_pred.Mean * p2_cd105_stemfit_pred.Area, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_cd105_stemfit_target.Mean * p4_cd105_stemfit_target.Area, p4_cd105_stemfit_pred.Mean * p4_cd105_stemfit_pred.Area, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_cd105_stemfit_target.Mean * p6_cd105_stemfit_target.Area, p6_cd105_stemfit_pred.Mean * p6_cd105_stemfit_pred.Area, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_cd105_stemfit_target.Mean * p8_cd105_stemfit_target.Area, p8_cd105_stemfit_pred.Mean * p8_cd105_stemfit_pred.Area, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_cd105_stemfit_target.Mean * p10_cd105_stemfit_target.Area, p10_cd105_stemfit_pred.Mean * p10_cd105_stemfit_pred.Area, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("CD105")
plt.xlabel ("Total Target Intensity")
plt.ylabel ("Total Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_p16_FBS_target.Mean * p2_p16_FBS_target.Area, p2_p16_FBS_pred.Mean * p2_p16_FBS_pred.Area, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_p16_FBS_target.Mean * p4_p16_FBS_target.Area, p4_p16_FBS_pred.Mean * p4_p16_FBS_pred.Area, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_p16_FBS_target.Mean * p6_p16_FBS_target.Area, p6_p16_FBS_pred.Mean * p6_p16_FBS_pred.Area, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_p16_FBS_target.Mean * p8_p16_FBS_target.Area, p8_p16_FBS_pred.Mean * p8_p16_FBS_pred.Area, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_p16_FBS_target.Mean * p10_p16_FBS_target.Area, p10_p16_FBS_pred.Mean * p10_p16_FBS_pred.Area, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_p16_stemfit_target.Mean * p2_p16_stemfit_target.Area, p2_p16_stemfit_pred.Mean * p2_p16_stemfit_pred.Area, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_p16_stemfit_target.Mean * p4_p16_stemfit_target.Area, p4_p16_stemfit_pred.Mean * p4_p16_stemfit_pred.Area, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_p16_stemfit_target.Mean * p6_p16_stemfit_target.Area, p6_p16_stemfit_pred.Mean * p6_p16_stemfit_pred.Area, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_p16_stemfit_target.Mean * p8_p16_stemfit_target.Area, p8_p16_stemfit_pred.Mean * p8_p16_stemfit_pred.Area, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_p16_stemfit_target.Mean * p10_p16_stemfit_target.Area, p10_p16_stemfit_pred.Mean * p10_p16_stemfit_pred.Area, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("p16")
plt.xlabel ("Total Target Intensity")
plt.ylabel ("Total Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_CCND2_FBS_target.Mean * p2_CCND2_FBS_target.Area, p2_CCND2_FBS_pred.Mean * p2_CCND2_FBS_pred.Area, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_CCND2_FBS_target.Mean * p4_CCND2_FBS_target.Area, p4_CCND2_FBS_pred.Mean * p4_CCND2_FBS_pred.Area, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_CCND2_FBS_target.Mean * p6_CCND2_FBS_target.Area, p6_CCND2_FBS_pred.Mean * p6_CCND2_FBS_pred.Area, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_CCND2_FBS_target.Mean * p8_CCND2_FBS_target.Area, p8_CCND2_FBS_pred.Mean * p8_CCND2_FBS_pred.Area, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_CCND2_FBS_target.Mean * p10_CCND2_FBS_target.Area, p10_CCND2_FBS_pred.Mean * p10_CCND2_FBS_pred.Area, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_CCND2_stemfit_target.Mean * p2_CCND2_stemfit_target.Area, p2_CCND2_stemfit_pred.Mean * p2_CCND2_stemfit_pred.Area, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_CCND2_stemfit_target.Mean * p4_CCND2_stemfit_target.Area, p4_CCND2_stemfit_pred.Mean * p4_CCND2_stemfit_pred.Area, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_CCND2_stemfit_target.Mean * p6_CCND2_stemfit_target.Area, p6_CCND2_stemfit_pred.Mean * p6_CCND2_stemfit_pred.Area, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_CCND2_stemfit_target.Mean * p8_CCND2_stemfit_target.Area, p8_CCND2_stemfit_pred.Mean * p8_CCND2_stemfit_pred.Area, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_CCND2_stemfit_target.Mean * p10_CCND2_stemfit_target.Area, p10_CCND2_stemfit_pred.Mean * p10_CCND2_stemfit_pred.Area, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("CCND2")
plt.xlabel ("Total Target Intensity")
plt.ylabel ("Total Prediction Intensity")
plt.legend()

# %%
plt.scatter (p2_p38_FBS_target.Mean * p2_p38_FBS_target.Area, p2_p38_FBS_pred.Mean * p2_p38_FBS_pred.Area, c = "#00c8ff", alpha = 0.5)
plt.scatter (p4_p38_FBS_target.Mean * p4_p38_FBS_target.Area, p4_p38_FBS_pred.Mean * p4_p38_FBS_pred.Area, c = "#0096ff", alpha = 0.5)
plt.scatter (p6_p38_FBS_target.Mean * p6_p38_FBS_target.Area, p6_p38_FBS_pred.Mean * p6_p38_FBS_pred.Area, c = "#0064ff", alpha = 0.5)
plt.scatter (p8_p38_FBS_target.Mean * p8_p38_FBS_target.Area, p8_p38_FBS_pred.Mean * p8_p38_FBS_pred.Area, c = "#0032ff", alpha = 0.5)
plt.scatter (p10_p38_FBS_target.Mean * p10_p38_FBS_target.Area, p10_p38_FBS_pred.Mean * p10_p38_FBS_pred.Area, c = "#0000ff", alpha = 0.5, label = "FBS")

plt.scatter (p2_p38_stemfit_target.Mean * p2_p38_stemfit_target.Area, p2_p38_stemfit_pred.Mean * p2_p38_stemfit_pred.Area, c = "#ffc800", alpha = 0.5)
plt.scatter (p4_p38_stemfit_target.Mean * p4_p38_stemfit_target.Area, p4_p38_stemfit_pred.Mean * p4_p38_stemfit_pred.Area, c = "#ff9600", alpha = 0.5)
plt.scatter (p6_p38_stemfit_target.Mean * p6_p38_stemfit_target.Area, p6_p38_stemfit_pred.Mean * p6_p38_stemfit_pred.Area, c = "#ff6400", alpha = 0.5)
plt.scatter (p8_p38_stemfit_target.Mean * p8_p38_stemfit_target.Area, p8_p38_stemfit_pred.Mean * p8_p38_stemfit_pred.Area, c = "#ff3200", alpha = 0.5)
plt.scatter (p10_p38_stemfit_target.Mean * p10_p38_stemfit_target.Area, p10_p38_stemfit_pred.Mean * p10_p38_stemfit_pred.Area, c = "#ff0000", alpha = 0.5, label = "Stemfit")

plt.title ("p38")
plt.xlabel ("Total Target Intensity")
plt.ylabel ("Total Prediction Intensity")
plt.legend()
